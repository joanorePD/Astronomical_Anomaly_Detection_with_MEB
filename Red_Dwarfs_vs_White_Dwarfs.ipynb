# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time

from alg_functions import *

# %%
# %pip install astroML
# Out:
# Requirement already satisfied: astroML in c:\users\crist\appdata\local\programs\python\python38\lib\site-packages (1.0.2.post1)
# Requirement already satisfied: scikit-learn>=0.18 in c:\users\crist\appdata\local\programs\python\python38\lib\site-packages (from astroML) (1.3.1)
# Requirement already satisfied: numpy>=1.13 in c:\users\crist\appdata\local\programs\python\python38\lib\site-packages (from astroML) (1.24.3)
# Requirement already satisfied: scipy>=0.18 in c:\users\crist\appdata\local\programs\python\python38\lib\site-packages (from astroML) (1.10.1)
# Requirement already satisfied: matplotlib>=3.0 in c:\users\crist\appdata\local\programs\python\python38\lib\site-packages (from astroML) (3.7.3)
# Requirement already satisfied: astropy>=3.0 in c:\users\crist\appdata\local\programs\python\python38\lib\site-packages (from astroML) (5.2.2)
# Requirement already satisfied: pyerfa>=2.0 in c:\users\crist\appdata\local\programs\python\python38\lib\site-packages (from astropy>=3.0->astroML) (2.0.0.3)
# Requirement already satisfied: PyYAML>=3.13 in c:\users\crist\appdata\local\programs\python\python38\lib\site-packages (from astropy>=3.0->astroML) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in c:\users\crist\appdata\roaming\python\python38\site-packages (from astropy>=3.0->astroML) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\crist\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.0->astroML) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\crist\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.0->astroML) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\crist\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.0->astroML) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\crist\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.0->astroML) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\crist\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.0->astroML) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\crist\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.0->astroML) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\crist\appdata\roaming\python\python38\site-packages (from matplotlib>=3.0->astroML) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\crist\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.0->astroML) (6.1.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\crist\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn>=0.18->astroML) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\crist\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn>=0.18->astroML) (3.2.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\crist\appdata\roaming\python\python38\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.0->astroML) (3.16.2)
# Requirement already satisfied: six>=1.5 in c:\users\crist\appdata\local\programs\python\python38\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0->astroML) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Obtain the Data

# %%
red_dwarfs = pd.read_csv('datasets/red_dwarfs.csv')
white_dwarfs = pd.read_csv('datasets/white_dwarfs.csv')

red_dwarfs['type'] = 'red'
white_dwarfs['type'] = 'white'

red_dwarfs = red_dwarfs[red_dwarfs['subclass'].str.startswith('K') | red_dwarfs['subclass'].str.startswith('M')]
white_dwarfs = white_dwarfs[white_dwarfs['subclass'] == 'WD']

red_dwarfs = red_dwarfs.iloc[:2000]
white_dwarfs = white_dwarfs.iloc[:2000]

dwarfs = pd.concat([red_dwarfs, white_dwarfs], ignore_index=True)

dwarfs = dwarfs.dropna()

display(dwarfs.head())
# Out:
#    spectroFlux_u  spectroFlux_g  spectroFlux_r  spectroFlux_i  spectroFlux_z  \
# 0       0.690362       2.639864       6.609772       9.040903       10.89239
# 1       1.696024       5.127242      11.380340      15.288570       18.13893
# 2       1.939370       6.556342      14.391160      19.006530       22.24492
# 3       2.038488       9.414086      19.352240      25.074530       29.21216
# 4       1.535014       5.447570      11.538370      15.077310       20.65042
#
#   class subclass type
# 0  STAR       K1  red
# 1  STAR       K1  red
# 2  STAR       K1  red
# 3  STAR       K1  red
# 4  STAR       K1  red

# %%
dwarfs['u-g'] = dwarfs['spectroFlux_u'] - dwarfs['spectroFlux_g']
dwarfs['g-r'] = dwarfs['spectroFlux_g'] - dwarfs['spectroFlux_r']
dwarfs['r-i'] = dwarfs['spectroFlux_r'] - dwarfs['spectroFlux_i']
dwarfs['i-z'] = dwarfs['spectroFlux_i'] - dwarfs['spectroFlux_z']
dwarfs['u-r'] = dwarfs['spectroFlux_u'] - dwarfs['spectroFlux_r']
dwarfs['r-z'] = dwarfs['spectroFlux_r'] - dwarfs['spectroFlux_z']
dwarfs['u-z'] = dwarfs['spectroFlux_u'] - dwarfs['spectroFlux_z']

pred_columns_dwarfs = ['u-g', 'g-r', 'r-i', 'i-z']

display(dwarfs.head())
# Out:
#    spectroFlux_u  spectroFlux_g  spectroFlux_r  spectroFlux_i  spectroFlux_z  \
# 0       0.690362       2.639864       6.609772       9.040903       10.89239
# 1       1.696024       5.127242      11.380340      15.288570       18.13893
# 2       1.939370       6.556342      14.391160      19.006530       22.24492
# 3       2.038488       9.414086      19.352240      25.074530       29.21216
# 4       1.535014       5.447570      11.538370      15.077310       20.65042
#
#   class subclass type       u-g       g-r       r-i       i-z        u-r  \
# 0  STAR       K1  red -1.949502 -3.969908 -2.431131 -1.851487  -5.919410
# 1  STAR       K1  red -3.431218 -6.253098 -3.908230 -2.850360  -9.684316
# 2  STAR       K1  red -4.616972 -7.834818 -4.615370 -3.238390 -12.451790
# 3  STAR       K1  red -7.375598 -9.938154 -5.722290 -4.137630 -17.313752
# 4  STAR       K1  red -3.912556 -6.090800 -3.538940 -5.573110 -10.003356
#
#         r-z        u-z
# 0 -4.282618 -10.202028
# 1 -6.758590 -16.442906
# 2 -7.853760 -20.305550
# 3 -9.859920 -27.173672
# 4 -9.112050 -19.115406

# %% [markdown]
# # Algorithm 1

# %%
A = dwarfs[dwarfs['type'] == 'white'][['u-g', 'g-r', 'r-i', 'i-z']].values
for epsilon in [0.01, 0.001, 0.0001]:
    print('epsilon: ', epsilon)
    c, r, k, chi, timer = frank_wolfe_alg_MEB(epsilon, A)
    print('---------------')
# Out:
# epsilon:  0.01
# Center: [140.52804351 213.88566069  85.86509275  37.62491031]
# Radius: 325.05716271240453
# Iterations: 5
# CPU time: 0.09771966934204102
# Core Set Size: 4
# ---------------
# epsilon:  0.001
# Center: [140.72559632 216.15189978  87.89006649  39.14004694]
# Radius: 322.55120057514233
# Iterations: 11
# CPU time: 0.22409629821777344
# Core Set Size: 4
# ---------------
# epsilon:  0.0001
# Center: [140.74162857 216.37800544  88.09349715  39.2924501 ]
# Radius: 322.3039075882181
# Iterations: 17
# CPU time: 0.36678552627563477
# Core Set Size: 4
# ---------------

# %%
# Calculate the Euclidean distance from each point to the center
distances = np.linalg.norm(dwarfs[pred_columns_dwarfs] - c, axis=1)

# Add a new boolean column indicating whether the point is inside the ball
dwarfs['InsideBall'] = distances < r

measure_accuracy('red', 'white', dwarfs)
# Out:
#                 Metric        Count
# 0   True Positive (TP)  1999.000000
# 1  False Negative (FN)     1.000000
# 2   True Negative (TN)   426.000000
# 3  False Positive (FP)  1536.000000
# 4            Precision     0.565488
# 5               Recall     0.999500
# 6             F1 Score     0.722313
